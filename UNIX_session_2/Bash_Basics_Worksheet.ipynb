# %% [markdown]
# # Bash basics worksheet
#
# Complete each section in its own code cell. Work in a fresh practice copy made with `./make_practice_copy.sh`, or use paths under `${TMPDIR:-/tmp}`. Explain what each command changes before running it.

# %% [markdown]
# ## 1. Basic commands
#
# Create a directory named `my_folder`, list the current directory including hidden entries, print the working directory, then create and remove a disposable `test.txt`.

# %%
# Write and test your commands here.

# %% [markdown]
# ## 2. Working with files
#
# Create `notes.txt`, write “Hello World” to it without duplicating content on repeated runs, display it, and copy it to `backup_notes.txt`.

# %%
# Write and test your commands here.

# %% [markdown]
# ## 3. Navigation
#
# Write commands for the parent directory, home directory, and `/usr/local`. Predict each destination before using `pwd` to check.

# %%
# Write your commands here. Run navigation commands in a terminal because each %%bash cell starts a new shell.

# %% [markdown]
# ## 4. Permissions
#
# Add owner execute permission to `script.sh`, then set `rwxr-xr-x` with octal notation. Verify both changes with `ls -l`.

# %%
# Write and test your commands here.

# %% [markdown]
# ## 5. Searching
#
# Find lines beginning with “error:” in `log.txt`. Count lines containing “success” in `output.txt`.

# %%
# Write and test your commands here.

# %% [markdown]
# ## 6. Piping and redirection
#
# Write a directory listing to `filelist.txt`, then pipe its contents to a search for “notes”. Explain whether `cat` is necessary.

# %%
# Write and test your commands here.

# %% [markdown]
# ## 7. Scripting
#
# Write `backup.sh` so it creates a backup directory, safely copies matching `.txt` files, handles the no-match case, and reports what it copied.

# %%
# Write your script here, or create it in a text editor.

# %% [markdown]
# ## 8. Help, time, and exit status
#
# Open the manual for `ls` in a terminal, print the current date, run a successful and a failing command, and inspect `$?` immediately after each.

# %%
# Write and test the non-interactive commands here.
