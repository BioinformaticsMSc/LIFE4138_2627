# %% [markdown]
# # Bash loops worksheet
#
# Use one code cell per task. Prefer robust record reading and preview state-changing commands.

# %% [markdown]
# ## 1. Simple loop
#
# Write a Bash loop that prints the numbers 1 to 5.

# %%
# Write and test your solution here.

# %% [markdown]
# ## 2. Files
#
# Loop over `.txt` files, quote the filename, and handle the case where no file matches.

# %%
# Write and test your solution here.

# %% [markdown]
# ## 3. Records
#
# Read `users.txt` one line at a time and print `Processing user: [username]`. Preserve spaces in a line.

# %%
# Write and test your solution here.

# %% [markdown]
# ## 4. C-style loop
#
# Write a C-style Bash loop that counts from 1 to 5. Explain when this syntax is less readable than a list or brace expansion.

# %%
# Write and test your solution here.

# %% [markdown]
# ## 5. Nested loops
#
# Print combinations of numbers 1–3 and letters `a` and `b`.

# %%
# Write and test your solution here.

# %% [markdown]
# ## 6. Safe renaming
#
# Print a dry run that would add `new_` to each `.log` filename. Do not rename anything until the preview is correct.

# %%
# Write and test your solution here.

# %% [markdown]
# ## Bonus: URL status
#
# Read `urls.txt` with `while IFS= read -r`. Use `curl` to report reachability, and explain why network policy can affect the result.

# %%
# Write and test your solution here.
