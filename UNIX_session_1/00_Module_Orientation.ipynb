# %% [markdown]
# # LIFE4138 module orientation

# %% [markdown]
# ### Let the fun begin.

# %%
# %env SUNSHINE=true
# %env MOONLIGHT=true
# %env GOOD_TIMES=true
# %env BOOGIE=false

# %%
# !if [ "$SUNSHINE" = false ]; then echo "Blame it on the sunshine!"; else echo "Don't blame it on the sunshine!"; fi; if [ "$MOONLIGHT" = false ]; then echo "Blame it on the moonlight!"; else echo "Don't blame it on the moonlight!"; fi; if [ "$GOOD_TIMES" = false ]; then echo "Blame it on the good times!"; else echo "Don't blame it on the good times!"; fi; if [ "$BOOGIE" = false ]; then echo "Blame it on the boogie!"; else echo "Don't blame it on the boogie!"; fi

# %% [markdown]
#
# # Welcome to LIFE4138!
#
# ## Prof Matt Loose
# matt.loose@nottingham.ac.uk
#
# ## Dr Hannah Jackson
# hannah.jackson@nottingham.ac.uk
#
# ## Dr Laura Dean
# laura.dean@nottingham.ac.uk

# %% [markdown]
# # The team!
#
# Module convenor
#
# ## Dr Hannah Jackson
# hannah.jackson@nottingham.ac.uk
#
# ## Prof Matt Loose
# matt.loose@nottingham.ac.uk
#
# ## Dr Laura Dean
# laura.dean@nottingham.ac.uk
#
# The cavlary!
#
# <img src="data:image/jpeg;base64,..." alt="superherodog" style="width: 100%; max-width: 1000px; height: auto;">

# %% [markdown]
# <img src="https://raw.githubusercontent.com/LooseLab/LIFE4138/refs/heads/main/workshops/images/training.webp" alt="Class at work" style="width: 100%; max-width: 1000px; height: auto;">

# %% [markdown]
# <img src="https://raw.githubusercontent.com/LooseLab/LIFE4138/refs/heads/main/workshops/images/cheerytraining.webp" alt="Cheery class at work" style="width: 100%; max-width: 1000px; height: auto;">

# %% [markdown]
# # Module Goals
#
# ### Learn Unix
#
# ### Learn R
#
# ### Learn Python
#
# ### Become a coding expert!
#
# All by week 10!

# %% [markdown]
# # Module Goals
#
# ## Just kidding! (mostly)

# %% [markdown]
# We aim to teach you the basics, but most importantly we aim to teach you how to learn.
#
#
# **Give a Man a Fish, and You Feed Him for a Day. Teach a Man To Fish, and You Feed Him for a Lifetime.**
#
# We are giving you the fishing rod of Bioinformatics!
#
# <img src="https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExcGtjaHoybnFxN3RyMmp3MzdrcmJ2MThsejE1ZjQxMWpvazc0N2MyZSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/26tk0aLx4Aj4lxx3W/giphy.gif" alt="description" style="width: 100%; max-width: 600px; height: auto;">

# %% [markdown]
# # We want you to GROK!

# %% [markdown]
# **!!!!** Sadly this slide was written before the AI of the same name which I am not referencing here....

# %% [markdown]
# **GROK** To grok something means to understand it deeply and intuitively. The term suggests not just intellectual comprehension, but a thorough, almost instinctive understanding of a subject or concept. It implies that the person "groks" something so completely that they can fully internalize its meaning or function.
#
# For example, "I grok Bash scripting" would mean the person has an intuitive and complete understanding of writing scripts in Bash.

# %% [markdown]
# <img src="https://i.giphy.com/media/v1.Y2lkPTc5MGI3NjExZTNibDlrNW04ZXk1enZxaXJmYWV4eHJkOHFnc2tlZ3M5ODhnMHV3biZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/K1nPCEuN2rwG1zJg04/giphy.gif" alt="description" style="width: 100%; max-width: 400px; height: auto;">

# %% [markdown]
# # Talking of **Grok** and Fish...
#
# https://software-carpentry.org/
#
# Software carpentry is a key resource. We will not duplicate the material in those lessons BUT they will be orthogonal to what we do here.
#
# Go to software carpentry.
#
# Go through the materials.
#
# Use the knowledge you have gained to improve your bioinformatics life!

# %% [markdown]
# # Cheating
#
# Cheating is **wrong**.
#
# In the age of chatGPT/ClaudeAI/Bing/Grok/Custom LLMs (the list goes on)... it is easy to cheat. Ultimately cheating using these tools **will only hurt you**.
#
# Use them to enhance your learning, **NOT** to replace it.
#
# We will try and demonstrate **ethical** use of tools such as these in coding.
#
# We will also refer you to "CheatSheets" which provide simple guides to common problems.
#
# <img src="https://raw.githubusercontent.com/LooseLab/LIFE4138/refs/heads/main/workshops/images/cheerytraining.webp" alt="Cheery class at work" style="width: 100%; max-width: 600px; height: auto;">

# %% [markdown]
# # ChatGPT/Codex/Claude Code/GROK/Copilot/DeepThought/ etc
#
#
# The use of LLMs to write assignments, generate code in its entirety, solve all your problems and be awarded a degree is **forbidden**. It is academic misconduct, and you will face the relevant consequences.
#
# However - you are encouraged to use search engines, the internet, self training courses and to appropriately use LLMs in your studies.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/BioinformaticsMSc/LIFE4138_2627/main/images/2026AIClassroom.png" alt="AI class at work" style="width: 100%; max-width: 600px; height: auto;">

# %% [markdown]
# # Module Format
#
#
# We will meet twice a week, on Tuesday and Friday (sigh). In each session it will be a mix of teaching, workshops and self learning.
#
# There will be **homework**. Please complete it!

# %% [markdown]
# # What we need from you:
#
# - **Feedback:** When the time comes, fill in the SEM forms and tell us how to improve (and where we're great!). Please also talk about the module in the SSFs etc.
# - **Proactive-ness:** If you're stuck with something, let us know so we can help you.
# - **Engagement:** Come to the sessions ready to learn. Try and complete homework before the session, it **will** help to consolidate what you've learned.

# %% [markdown]
# # Assessment
#
# The assessment pattern is:
#
# - **Exam (25%)**: an in-person, one-hour assessment, predominantly multiple choice.
# - **Coursework (75%)**: a coding challenge using R and Python.
#
# Always use the current module handbook, Moodle page, and your official timetable for dates, submission times, and feedback arrangements. Cached teaching notebooks may be older than the live module information.

# %% [markdown]
# # A brief interlude from Laura!
#
# ### Making sure you're set up, and an introduction to Ada
#
# <img src=https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExejc5Z3NvMjM0OHMzM3ZudG45MWc2cmU0NjBlYmlmazRscjIwem8ydSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/lAoJiJLWTiJ5eKCxWg/giphy.gif alt="drawing" width="600"/>
